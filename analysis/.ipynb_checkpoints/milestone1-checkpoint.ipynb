# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/MY2020_Fuel_Consumption_Ratings.csv', encoding="unicode-escape")
df
# Out:
#                 Model                                               Make  \
# 0                Year                                                NaN
# 1                2020                                              Acura
# 2                2020                                              Acura
# 3                2020                                              Acura
# 4                2020                                              Acura
# ..                ...                                                ...
# 911               NaN                                    N = natural gas
# 912  Fuel consumption  City and highway fuel consumption ratings are ...
# 913     CO2 emissions  the tailpipe emissions of carbon dioxide (in g...
# 914        CO2 rating  the tailpipe emissions of carbon dioxide rated...
# 915       Smog rating  the tailpipe emissions of smog-forming polluta...
#
#                Model.1 Vehicle Class Engine Size  Cylinders Transmission  \
# ...
